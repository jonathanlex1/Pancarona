# %% [markdown]
# # Running Shoes Clustering on Tokopedia

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv('./dataset/products.csv')
df.head()
# Out:
#                        product_name  rating_number  rating_counter  \
# 0          910 Nineten Geist Ekiden              5              17
# 1          910 Nineten Geist Ekiden              5               1
# 2               910 Nineten Aurorun              5               3
# 3           910 Nineten Kanzaki 2.0              5               2
# 4  910 Nineten Yuka Accel Addiction              5               2
#
#   product_price    price_range  number_reviews  sold_count  satisfaction  \
# 0  Rp479,900.00  400000-500000               8          30           1.0
# 1  Rp549,900.00  500000-600000               0           1           1.0
# 2  Rp599,900.00  500000-600000               0          12           1.0
# 3  Rp579,900.00  500000-600000               1           3           1.0
# 4  Rp529,900.00  500000-600000               1          11           1.0
#
#   satisfaction_range      shop_name  shop_rating  shop_rating_counter  \
# 0             90-100  Kayak Outdoor          5.0               176000
# 1             90-100  Kayak Outdoor          5.0               176000
# 2             90-100  Kayak Outdoor          5.0               176000
# 3             90-100  Kayak Outdoor          5.0               176000
# 4             90-100  Kayak Outdoor          5.0               176000
#
#                                  product_name_detail
# 0  Sepatu Lari 910 Nineten Geist Ekiden - Abu Tua...
# 1  Sepatu Running Trail 910 Nineten Geist Ekiden ...
# 2        Sepatu Lari 910 Nineten Aurorun - Navy/ungu
# 3  Sepatu running 910 Nineten Kanzaki 2.0 - Hitam...
# 4  Sepatu Lari 910 Nineten Yuka Accel Addiction -...

# %%
df[['price', 'sold_count', 'rating_number', 'rating_counter', 'satisfaction', 'number_reviews']]
